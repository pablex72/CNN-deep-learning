# %% [markdown]
# <a href="https://colab.research.google.com/github/pablex72/CNN-deep-learning/blob/main/submitting_images_tiff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Function to perform image analysis
def analyze_images(image1, image2):
    # Load the images
    img1 = cv2.imread(image1, cv2.IMREAD_GRAYSCALE)
    img2 = cv2.imread(image2, cv2.IMREAD_GRAYSCALE)

    if img1 is None or img2 is None:
        print("Error: Unable to load one or both images.")
        return

    # Perform image processing and analysis here
    # Example: Calculate the absolute difference between the two images
    difference = cv2.absdiff(img1, img2)

    # Display the images and analysis result
    plt.figure(figsize=(12, 6))

    plt.subplot(131)
    plt.title("Image 1")
    plt.imshow(img1, cmap='gray')

    plt.subplot(132)
    plt.title("Image 2")
    plt.imshow(img2, cmap='gray')

    plt.subplot(133)
    plt.title("Absolute Difference")
    plt.imshow(difference, cmap='gray')

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    # Replace these paths with the paths to your TIFF images
    image_path1 = "/content/image_export.tif"
    image_path2 = "/content/image_export_cog.tif"

    analyze_images(image_path1, image_path2)
# Out:
# Error: Unable to load one or both images.

# %%
pip install opencv-python numpy matplotlib

# %%
pip install rasterio matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 102.9 MB/s eta 0:00:00
# ...

# %%
import rasterio
import matplotlib.pyplot as plt

# Open the TIFF image file
with rasterio.open('/content/Sentinel-2.tif') as src:
    # Read the image data
    image_data = src.read(1)  # Assuming it's a single-band image, change index if necessary

    # Display the image using Matplotlib
    plt.figure(figsize=(8, 8))
    plt.imshow(image_data, cmap='gray')  # You can change the colormap as needed
    plt.title('TIFF Image')
    plt.colorbar()
    plt.show()

# %%
import rasterio
import matplotlib.pyplot as plt

# Open the TIFF image file
with rasterio.open('/content/Sentinel-2-Aaa.tif') as src:
    # Read the image data
    image_data = src.read(1)  # Assuming it's a single-band image, change index if necessary

    # Display the image using Matplotlib
    plt.figure(figsize=(8, 8))
    plt.imshow(image_data, cmap='gray')  # You can change the colormap as needed
    plt.title('TIFF Image')
    plt.colorbar()
    plt.show()

# %%
import rasterio
import matplotlib.pyplot as plt

# Open the TIFF image file
with rasterio.open('/content/Sentinel-2-lll.tif') as src:
    # Read the image data
    image_data = src.read(1)  # Assuming it's a single-band image, change index if necessary

    # Display the image using Matplotlib
    plt.figure(figsize=(8, 8))
    plt.imshow(image_data, cmap='grey')  # You can change the colormap as needed
    plt.title('TIFF Image')
    plt.colorbar()
    plt.show()

# %%
import rasterio
import matplotlib.pyplot as plt

# Open the first TIFF image file
with rasterio.open('/content/Sentinel-2-vege-20-09-27.tif') as src1:
    # Read the first image data
    image_data1 = src1.read(1)  # Assuming it's a single-band image, change index if necessary

# Open the second TIFF image file
with rasterio.open('/content/Sentinel-2-repro-21-01-10.tif') as src2:
    # Read the second image data
    image_data2 = src2.read(1)  # Assuming it's a single-band image, change index if necessary

# Create a 1x2 grid of subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Display the first image in the first subplot
axes[0].imshow(image_data1, cmap='Greens')  # You can change the colormap as needed
axes[0].set_title('Vegetative 2020-Sep-27')
axes[0].axis('off')  # Turn off the axis for the first subplot

# Display the second image in the second subplot
axes[1].imshow(image_data2, cmap='Greens')  # You can change the colormap as needed
axes[1].set_title('Reproductive 2021-Jan-10')
axes[1].axis('off')  # Turn off the axis for the second subplot

# Add a title for the entire figure
plt.suptitle('Side-by-Side Image Visualization')

# Show the subplots
plt.show()
